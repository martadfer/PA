# %%
# !pip install statsmodels

# %%
#!pip list | findstr pandas

# %%
#!pip install pandas --upgrade

# %%
import numpy as np
from pathlib import Path
import pandas as pd
import statsmodels.api as sm

from sklearn.linear_model import LogisticRegression

# %%
config_dirs = open("prefixo_dados.txt").readlines() 
DIR_PREFIXO = Path(config_dirs[0].strip()) 

DIRETORIO_PRINCIPAL =  DIR_PREFIXO / "PA_clean" / "kfold" 
DIR_KMEANS = DIRETORIO_PRINCIPAL / "KMeansRandom"
DIR_DICT = DIR_PREFIXO / "Projeto_PA" / "Projeto_PA_validado" / "DICT"
DIR_NMF = DIR_PREFIXO / "Projeto_PA" / "Projeto_PA_validado" / "NMF"

DIR_REGLOGIST =  DIR_PREFIXO / "PA_clean" / "kfold" / "reglogist"
#DIR_KMEANS = DIR_PREFIXO / "Projeto_PA/Projeto_PA_validado/KMeansRandom" / f"KMEANS_approach_{abordagem}_todos_pacientes.csv"

# %%
caminho = DIRETORIO_PRINCIPAL / DIR_KMEANS
caminho
diretorios = {'dict':DIR_DICT,'kmeans':DIR_KMEANS, 'nmf':DIR_NMF}

nome_abordagem = {'cadastro':"_approach_cadastro", 'doenca':"_approach_doenca",
                  'medidas':"_approach_medidas",'estatistica':"_approach_estatistica",
                 'escolho_doenca':"_approach_escolho_doenca", 'categorias':"_approach_classes",
                 'medidas_masc':"_approach_medidas_masc",'medidas_fem':"_approach_medidas_fem",
                 'medidas_diast':"_approach_medidas_diastolica", 'medidas_sist':"_approach_medidas_sistolica",
                 'medidas_importantes':"_approach_medidas_importantes",
                 'simplificado':"_approach_simplificado" }

# %%
# Análise é uma opção do dicionário criado na célula acima
#algoritmo = input("Informe a analise ")
algoritmo = 'kmeans'

caminho_medidas = diretorios[algoritmo.lower()]/ f"{algoritmo.upper()}{nome_abordagem['medidas']}"
caminho_estatistica = diretorios[algoritmo.lower()]/ f"{algoritmo.upper()}{nome_abordagem['estatistica']}"
caminho_doenca = diretorios[algoritmo.lower()]/ f"{algoritmo.upper()}{nome_abordagem['doenca']}"
caminho_cadastro = diretorios[algoritmo.lower()]/ f"{algoritmo.upper()}{nome_abordagem['cadastro']}"
caminho_escolho_doenca = diretorios[algoritmo.lower()]/ f"{algoritmo.upper()}{nome_abordagem['escolho_doenca']}"
caminho_categorias = diretorios[algoritmo.lower()]/ f"{algoritmo.upper()}{nome_abordagem['categorias']}"
caminho_medidas_masc = diretorios[algoritmo.lower()]/ f"{algoritmo.upper()}{nome_abordagem['medidas_masc']}"
caminho_medidas_fem = diretorios[algoritmo.lower()]/ f"{algoritmo.upper()}{nome_abordagem['medidas_fem']}"
caminho_medidas_diast = diretorios[algoritmo.lower()]/ f"{algoritmo.upper()}{nome_abordagem['medidas_diast']}"
caminho_medidas_sist = diretorios[algoritmo.lower()]/ f"{algoritmo.upper()}{nome_abordagem['medidas_sist']}"
caminho_medidas_importantes = diretorios[algoritmo.lower()]/ f"{algoritmo.upper()}{nome_abordagem['medidas_importantes']}"
caminho_simplificado = diretorios[algoritmo.lower()]/ f"{algoritmo.upper()}{nome_abordagem['simplificado']}"

# %%
# Diferentes Abordagens

abordagem_cadastro    = list()
abordagem_medidas     = list()
abordagem_estatistica = list()
abordagem_doenca      = list()
abordagem_escolho_doenca = list()
abordagem_categorias  = list()
abordagem_medidas_masc = list()
abordagem_medidas_fem   = list()
abordagem_medidas_importantes   = list()
abordagem_simplificado    = list()

try:
    grupo_leitura = 1
    while 1:

        abordagem_estatistica.append(pd.read_csv(f"{caminho_estatistica}_grupo_{grupo_leitura}.csv", sep=";", encoding='latin1'))
        grupo_leitura += 1   
except:
    pass

try:
    grupo_leitura = 1
    while 1:

        abordagem_medidas.append(pd.read_csv(f"{caminho_medidas}_grupo_{grupo_leitura}.csv", sep=";", encoding='latin1'))
        grupo_leitura += 1

except:
    pass

try:
    grupo_leitura = 1
    while 1:

        abordagem_doenca.append(pd.read_csv(f"{caminho_doenca}_grupo_{grupo_leitura}.csv", sep=";", encoding='latin1'))
        grupo_leitura += 1
except:
    pass

try:
    grupo_leitura = 1
    while 1:

        abordagem_cadastro.append(pd.read_csv(f"{caminho_cadastro}_grupo_{grupo_leitura}.csv", sep=";", encoding='latin1'))
        grupo_leitura += 1

except:
    pass

try:
    grupo_leitura = 1
    while 1:

        abordagem_escolho_doenca.append(pd.read_csv(f"{caminho_escolho_doenca}_grupo_{grupo_leitura}.csv", sep=";", encoding='latin1'))
        grupo_leitura += 1

except:
    pass

try:
    grupo_leitura = 1
    while 1:

        abordagem_categorias.append(pd.read_csv(f"{caminho_categorias}_grupo_{grupo_leitura}.csv", sep=";", encoding='latin1'))
        grupo_leitura += 1

except:
    pass

try:
    grupo_leitura = 1
    while 1:

        abordagem_medidas_masc.append(pd.read_csv(f"{caminho_medidas_masc}_grupo_{grupo_leitura}.csv", sep=";", encoding='latin1'))
        grupo_leitura += 1

except:
    pass

try:
    grupo_leitura = 1
    while 1:

        abordagem_medidas_fem.append(pd.read_csv(f"{caminho_medidas_fem}_grupo_{grupo_leitura}.csv", sep=";", encoding='latin1'))
        grupo_leitura += 1

except:
    pass

try:
    grupo_leitura = 1
    while 1:

        abordagem_medidas_importantes.append(pd.read_csv(f"{caminho_medidas_importantes}_grupo_{grupo_leitura}.csv", sep=";", encoding='latin1'))
        grupo_leitura += 1

except:
    pass

try:
    grupo_leitura = 1
    while 1:

        abordagem_simplificado.append(pd.read_csv(f"{caminho_simplificado}_grupo_{grupo_leitura}.csv", sep=";", encoding='latin1'))
        grupo_leitura += 1

except:
    pass

# %%
mapa_variaveis = abordagem_medidas[0].copy()
genero_0_1 = {'genero':{'F':0, 'M':1}}
mapa_variaveis = mapa_variaveis.replace(genero_0_1)
mapa_variaveis['Whitecoat'] = mapa_variaveis['Whitecoat'].astype('int')
mapa_variaveis[['Whitecoat','grupo', 'genero']]
# Out:
#       Whitecoat  grupo  genero
# 0             1      1       0
# 1             0      1       0
# 2             0      1       0
# 3             1      1       0
# 4             1      1       0
# ...         ...    ...     ...
# 2603          0      1       0
# 2604          0      1       0
# 2605          1      1       0
# 2606          1      1       0
# 2607          1      1       0
#
# [2608 rows x 3 columns]

# %%
#mapa_variaveis[['cat. idade', 'cat. imc', 'genero', 'Whitecoat']]

# %%
# Cabeçalho
# Var Independente = grupo, genero
# Var dependente = doença
# Grupo = número

def p_value(x_independente, y_dependente, file, grupo, doenca, independente):
    with open(file,'a+') as f:
        sm_model = sm.MNLogit(y_dependente, x_independente).fit()
        # print(sm_model.pvalues)
        print(f'Var Independente = {independente}\nVar dependente = {doenca}\nGrupo = {grupo}\n\n')
        print("\n\n=================================Model Summary================================\n\n")
        print(sm_model.summary())
        
        clf = LogisticRegression(random_state=0).fit(x_independente, y_dependente)
        clf.predict(x_independente)
        print("\n\n=================================Predict Proba================================\n\n")
        print(clf.predict_proba(x_independente))
        print("\n\n====================================Score=====================================\n\n")
        print(clf.score(x_independente, y_dependente))
        
        f.write(f'Var Independente = {independente}\nVar dependente = {doenca}\nGrupo = {grupo}\n')
        f.write("\n\n=================================Model Summary================================\n\n")
        f.write(str(sm_model.summary()))
        
        f.write("\n\n=================================Predict Proba================================\n\n")
        f.write(str(clf.predict_proba(x_independente)))
        f.write("\n\n====================================Score=====================================\n\n")
        f.write(str(clf.score(x_independente, y_dependente)))

        #X = np.asarray(grupos[0]["Whitecoat"]).astype(int)[:, np.newaxis]
        #sm_model = sm.Logit(grupos[0]["genero"], sm.add_constant(X)).fit(disp=0)
        #print(sm_model.pvalues)
        #sm_model.summary()
    
x_independente = mapa_variaveis[['grupo', 'genero']]
y_dependente = mapa_variaveis[['Whitecoat']]
doenca = 'Whitecoat'
independente = 'grupo, genero'
grupo = 1
file = DIR_REGLOGIST / f"reglogist_{doenca}_grupo{grupo}.txt"
f = open(DIR_REGLOGIST / f"reglogist_{doenca}_grupo{grupo}.txt",'w')
f.close()

p_value(x_independente, y_dependente, file, grupo, doenca, independente)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.646863
#          Iterations 4
# Var Independente = grupo, genero
# Var dependente = Whitecoat
# Grupo = 1
#
#
#
#
# =================================Model Summary================================
#
#
#                           MNLogit Regression Results
# ==============================================================================
# Dep. Variable:              Whitecoat   No. Observations:                 2608
# Model:                        MNLogit   Df Residuals:                     2606
# Method:                           MLE   Df Model:                            1
# Date:                Fri, 24 Mar 2023   Pseudo R-squ.:                 0.01558
# Time:                        12:25:06   Log-Likelihood:                -1687.0
# converged:                       True   LL-Null:                       -1713.7
# Covariance Type:            nonrobust   LLR p-value:                 2.714e-13
# ===============================================================================
# Whitecoat=1       coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------
# grupo           0.7624      0.051     14.871      0.000       0.662       0.863
# genero         -0.6263      0.086     -7.314      0.000      -0.794      -0.458
# ===============================================================================
#
#
# =================================Predict Proba================================
#
#
# [[0.31848569 0.68151431]
#  [0.31848569 0.68151431]
#  [0.31848569 0.68151431]
#  ...
#  [0.31848569 0.68151431]
#  [0.31848569 0.68151431]
#  [0.31848569 0.68151431]]
#
#
# ====================================Score=====================================
#
#
# 0.6334355828220859
# C:\Users\marta\anaconda3\lib\site-packages\sklearn\utils\validation.py:1111: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
ls_abordagens = [abordagem_cadastro, abordagem_medidas, abordagem_medidas_masc, abordagem_medidas_fem,
                 abordagem_categorias, abordagem_estatistica, abordagem_doenca, abordagem_escolho_doenca,
                 abordagem_simplificado]

ls_nomes = ['Demograficos','Medidas','Medidas Masc','Medidas Fem','Categorias', 'Estatistica',
            'Doenca', 'Escolho Doenca','Simplificado']

genero_0_1 = {'genero':{'F':0, 'M':1}}

doencas = [  'Hipotensao',
             'Sistolica Isolada',
             'Diastolica Isolada',
             'Dipping',
             'Non Dipping',
             'Extreme Dipping',
             'Reverse Dipping',
             'Morning Surge',
             'Masked',
             'Whitecoat',
             'Normotenso']

independente = ['grupo', 'genero']
#p_value(x_independente, y_dependente, file, grupo, doenca, independente)
for abordagem,ls_dataset in zip(ls_nomes,ls_abordagens):
    for doenca in doencas:
        file = DIR_REGLOGIST / f"reglogist_{abordagem.replace(' ','_').lower()}_{doenca.replace(' ','_').lower()}.txt"
        f = open(file,'w')
        f.close()
        for grupo,dataset in zip(np.array(range(len(ls_dataset)))+1,ls_dataset):
            #print(np.array(range(len(ls_dataset)))+1)
            dataset_grupo = dataset.copy()
            dataset_grupo = dataset_grupo.replace(genero_0_1)
            dataset_grupo[doenca] = dataset_grupo[doenca].astype('int')
            
            x_independente = dataset_grupo[independente]
            y_dependente = dataset_grupo[[doenca]]
            #print(x_independente)
            #print(y_dependente)
            
            try:
                p_value(x_independente, y_dependente, file, grupo, doenca, independente)
            except:
                pass
# Out:
# Optimization terminated successfully.
#          Current function value: 0.053043
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.496094
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.428068
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.688868
#          Iterations 4
# Var Independente = ['grupo', 'genero']
# Var dependente = Hipotensao
# Grupo = 5
#
#
#
#
# =================================Model Summary================================
#
#
#                           MNLogit Regression Results
# ==============================================================================
# Dep. Variable:             Hipotensao   No. Observations:                 1250
# Model:                        MNLogit   Df Residuals:                     1248
# Method:                           MLE   Df Model:                            1
# Date:                Fri, 24 Mar 2023   Pseudo R-squ.:               0.0003770
# Time:                        12:25:07   Log-Likelihood:                -861.08
# converged:                       True   LL-Null:                       -861.41
# Covariance Type:            nonrobust   LLR p-value:                    0.4203
# ================================================================================
# Hipotensao=1       coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# grupo           -0.0227      0.020     -1.142      0.253      -0.062       0.016
# genero          -0.0977      0.121     -0.806      0.420      -0.335       0.140
# ================================================================================
#
#
# =================================Predict Proba================================
#
#
# [[0.55254882 0.44745118]
#  [0.55254882 0.44745118]
#  [0.55254882 0.44745118]
#  ...
#  [0.52862257 0.47137743]
#  [0.52862257 0.47137743]
#  [0.55254882 0.44745118]]
#
#
# ====================================Score=====================================
#
#
# 0.5448
# Optimization terminated successfully.
#          Current function value: 0.024670
#          Iterations 10
# Var Independente = ['grupo', 'genero']
# Var dependente = Hipotensao
# Grupo = 6
#
#
#
#
# =================================Model Summary================================
#
#
#                           MNLogit Regression Results
# ==============================================================================
# Dep. Variable:             Hipotensao   No. Observations:                 3737
# Model:                        MNLogit   Df Residuals:                     3735
# Method:                           MLE   Df Model:                            1
# Date:                Fri, 24 Mar 2023   Pseudo R-squ.:               3.747e-11
# Time:                        12:25:07   Log-Likelihood:                -92.191
# converged:                       True   LL-Null:                       -92.191
# Covariance Type:            nonrobust   LLR p-value:                    0.9999
# ================================================================================
# Hipotensao=1       coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# grupo            0.9054   1.69e+06   5.36e-07      1.000   -3.31e+06    3.31e+06
# genero           0.1509   1.01e+07   1.49e-08      1.000   -1.99e+07    1.99e+07
# ================================================================================
#
#
# =================================Predict Proba================================
#
#
# [[0.00374632 0.99625368]
#  [0.00374632 0.99625368]
#  [0.00374632 0.99625368]
#  ...
#  [0.00374632 0.99625368]
#  [0.00374632 0.99625368]
#  [0.00374632 0.99625368]]
#
#
# ====================================Score=====================================
#
#
# 0.9962536794219963
# Optimization terminated successfully.
#          Current function value: 0.014767
#          Iterations 10
# C:\Users\marta\anaconda3\lib\site-packages\sklearn\utils\validation.py:1111: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\marta\anaconda3\lib\site-packages\sklearn\utils\validation.py:1111: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Optimization terminated successfully.
#          Current function value: 0.006036
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.007768
#          Iterations 11
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.015297
#          Iterations: 35
# Var Independente = ['grupo', 'genero']
# Var dependente = Sistolica Isolada
# Grupo = 6
#
#
#
#
# =================================Model Summary================================
#
#
#                           MNLogit Regression Results
# ==============================================================================
# Dep. Variable:      Sistolica Isolada   No. Observations:                 3737
# Model:                        MNLogit   Df Residuals:                     3735
# Method:                           MLE   Df Model:                            1
# Date:                Fri, 24 Mar 2023   Pseudo R-squ.:               1.865e-11
# Time:                        12:25:07   Log-Likelihood:                -57.164
# converged:                      False   LL-Null:                       -57.164
# Covariance Type:            nonrobust   LLR p-value:                     1.000
# =======================================================================================
# Sistolica Isolada=1       coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# grupo                  -0.9964        nan        nan        nan         nan         nan
# genero                 -0.1661        nan        nan        nan         nan         nan
# =======================================================================================
# C:\Users\marta\anaconda3\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# C:\Users\marta\anaconda3\lib\site-packages\statsmodels\discrete\discrete_model.py:4247: RuntimeWarning: invalid value encountered in sqrt
#   bse = np.sqrt(np.diag(self.cov_params()))
# C:\Users\marta\anaconda3\lib\site-packages\sklearn\utils\validation.py:1111: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# =================================Predict Proba================================
#
#
# [[0.99785925 0.00214075]
#  [0.99785925 0.00214075]
#  [0.99785925 0.00214075]
#  ...
#  [0.99785925 0.00214075]
#  [0.99785925 0.00214075]
#  [0.99785925 0.00214075]]
#
#
# ====================================Score=====================================
#
#
# 0.9978592453839978
# Optimization terminated successfully.
#          Current function value: 0.035177
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.017904
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.050502
#          Iterations 9
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.021642
#          Iterations: 35
# Var Independente = ['grupo', 'genero']
# Var dependente = Diastolica Isolada
# Grupo = 6
#
#
#
#
# =================================Model Summary================================
#
#
#                           MNLogit Regression Results
# ==============================================================================
# Dep. Variable:     Diastolica Isolada   No. Observations:                 3737
# Model:                        MNLogit   Df Residuals:                     3735
# Method:                           MLE   Df Model:                            1
# Date:                Fri, 24 Mar 2023   Pseudo R-squ.:               3.585e-11
# Time:                        12:25:07   Log-Likelihood:                -80.874
# converged:                      False   LL-Null:                       -80.874
# Covariance Type:            nonrobust   LLR p-value:                    0.9999
# ========================================================================================
# Diastolica Isolada=1       coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# grupo                   -0.9305   8.63e+05  -1.08e-06      1.000   -1.69e+06    1.69e+06
# genero                  -0.1551   5.18e+06  -2.99e-08      1.000   -1.02e+07    1.02e+07
# ========================================================================================
#
#
# =================================Predict Proba================================
#
#
# [[0.99678883 0.00321117]
#  [0.99678883 0.00321117]
#  [0.99678883 0.00321117]
#  ...
#  [0.99678883 0.00321117]
#  [0.99678883 0.00321117]
#  [0.99678883 0.00321117]]
#
#
# ====================================Score=====================================
#
#
# 0.9967888680759968
# Optimization terminated successfully.
#          Current function value: 0.632413
#          Iterations 5
# C:\Users\marta\anaconda3\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# C:\Users\marta\anaconda3\lib\site-packages\sklearn\utils\validation.py:1111: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\marta\anaconda3\lib\site-packages\sklearn\utils\validation.py:1111: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Var Independente = ['grupo', 'genero']
# Var dependente = Dipping
# Grupo = 1
#
#
#
#
# =================================Model Summary================================
#
#
#                           MNLogit Regression Results
# ==============================================================================
# Dep. Variable:                Dipping   No. Observations:                 2979
# Model:                        MNLogit   Df Residuals:                     2977
# Method:                           MLE   Df Model:                            1
# Date:                Fri, 24 Mar 2023   Pseudo R-squ.:               0.0008745
# Time:                        12:25:07   Log-Likelihood:                -1884.0
# converged:                       True   LL-Null:                       -1885.6
# Covariance Type:            nonrobust   LLR p-value:                   0.06937
# ==============================================================================
#  Dipping=1       coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# grupo         -0.7080      0.039    -18.048      0.000      -0.785      -0.631
# genero        -0.6783      0.397     -1.708      0.088      -1.457       0.100
# ==============================================================================
#
#
# =================================Predict Proba================================
#
#
# [[0.67015595 0.32984405]
#  [0.67015595 0.32984405]
#  [0.67015595 0.32984405]
#  ...
#  [0.67015595 0.32984405]
#  [0.67015595 0.32984405]
#  [0.67015595 0.32984405]]
#
#
# ====================================Score=====================================
#
#
# 0.6717019133937563
# Optimization terminated successfully.
#          Current function value: 0.619866
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.598702
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.661092
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.602496
#          Iterations 5
# Var Independente = ['grupo', 'genero']
# Var dependente = Dipping
# Grupo = 5
#
#
#
#
# =================================Model Summary================================
#
#
#                           MNLogit Regression Results
# ==============================================================================
# Dep. Variable:                Dipping   No. Observations:                 1250
# Model:                        MNLogit   Df Residuals:                     1248
# Method:                           MLE   Df Model:                            1
# Date:                Fri, 24 Mar 2023   Pseudo R-squ.:                0.004704
# Time:                        12:25:07   Log-Likelihood:                -753.12
# converged:                       True   LL-Null:                       -756.68
# Covariance Type:            nonrobust   LLR p-value:                  0.007629
# ==============================================================================
#  Dipping=1       coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# grupo         -0.2257      0.023     -9.760      0.000      -0.271      -0.180
# genero         0.3616      0.137      2.635      0.008       0.093       0.631
# ==============================================================================
#
#
# =================================Predict Proba================================
#
#
# [[0.68326027 0.31673973]
#  [0.68326027 0.31673973]
#  [0.68326027 0.31673973]
#  ...
#  [0.75467919 0.24532081]
#  [0.75467919 0.24532081]
#  [0.68326027 0.31673973]]
#
#
# ====================================Score=====================================
#
#
# 0.7064
# C:\Users\marta\anaconda3\lib\site-packages\sklearn\utils\validation.py:1111: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\marta\anaconda3\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# C:\Users\marta\anaconda3\lib\site-packages\statsmodels\discrete\discrete_model.py:4247: RuntimeWarning: invalid value encountered in sqrt
#   bse = np.sqrt(np.diag(self.cov_params()))
# C:\Users\marta\anaconda3\lib\site-packages\sklearn\utils\validation.py:1111: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\marta\anaconda3\lib\site-packages\sklearn\utils\validation.py:1111: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.642693
#          Iterations: 35
# Var Independente = ['grupo', 'genero']
# Var dependente = Dipping
# Grupo = 6
#
#
#
#
# =================================Model Summary================================
#
#
#                           MNLogit Regression Results
# ==============================================================================
# Dep. Variable:                Dipping   No. Observations:                 3737
# Model:                        MNLogit   Df Residuals:                     3735
# Method:                           MLE   Df Model:                            1
# Date:                Fri, 24 Mar 2023   Pseudo R-squ.:               6.006e-11
# Time:                        12:25:07   Log-Likelihood:                -2401.7
# converged:                      False   LL-Null:                       -2401.7
# Covariance Type:            nonrobust   LLR p-value:                    0.9996
# ==============================================================================
#  Dipping=1       coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# grupo         -0.1057        nan        nan        nan         nan         nan
# genero        -0.0176        nan        nan        nan         nan         nan
# ==============================================================================
#
#
# =================================Predict Proba================================
#
#
# [[0.65747311 0.34252689]
#  [0.65747311 0.34252689]
#  [0.65747311 0.34252689]
#  ...
#  [0.65747311 0.34252689]
#  [0.65747311 0.34252689]
#  [0.65747311 0.34252689]]
#
#
# ====================================Score=====================================
#
#
# 0.6574792614396575
# Optimization terminated successfully.
#          Current function value: 0.691249
#          Iterations 4
# Var Independente = ['grupo', 'genero']
# Var dependente = Non Dipping
# Grupo = 1
#
#
#
#
# =================================Model Summary================================
#
#
#                           MNLogit Regression Results
# ==============================================================================
# Dep. Variable:            Non Dipping   No. Observations:                 2979
# Model:                        MNLogit   Df Residuals:                     2977
# Method:                           MLE   Df Model:                            1
# Date:                Fri, 24 Mar 2023   Pseudo R-squ.:               0.0002484
# Time:                        12:25:07   Log-Likelihood:                -2059.2
# converged:                       True   LL-Null:                       -2059.7
# Covariance Type:            nonrobust   LLR p-value:                    0.3118
# =================================================================================
# Non Dipping=1       coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# grupo            -0.1220      0.037     -3.300      0.001      -0.194      -0.050
# genero            0.3226      0.320      1.008      0.313      -0.304       0.950
# =================================================================================
#
#
# =================================Predict Proba================================
#
#
# [[0.53035315 0.46964685]
#  [0.53035315 0.46964685]
#  [0.53035315 0.46964685]
#  ...
#  [0.53035315 0.46964685]
#  [0.53035315 0.46964685]
#  [0.53035315 0.46964685]]
#
#
# ====================================Score=====================================
#
#
# 0.5307150050352467
# Optimization terminated successfully.
#          Current function value: 0.690923
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.689190
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.682450
#          Iterations 4
# C:\Users\marta\anaconda3\lib\site-packages\sklearn\utils\validation.py:1111: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\marta\anaconda3\lib\site-packages\sklearn\utils\validation.py:1111: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Var Independente = ['grupo', 'genero']
# Var dependente = Non Dipping
# Grupo = 4
#
#
#
#
# =================================Model Summary================================
#
#
#                           MNLogit Regression Results
# ==============================================================================
# Dep. Variable:            Non Dipping   No. Observations:                 4082
# Model:                        MNLogit   Df Residuals:                     4080
# Method:                           MLE   Df Model:                            1
# Date:                Fri, 24 Mar 2023   Pseudo R-squ.:               1.543e-11
# Time:                        12:25:07   Log-Likelihood:                -2785.8
# converged:                       True   LL-Null:                       -2785.8
# Covariance Type:            nonrobust   LLR p-value:                    0.9998
# =================================================================================
# Non Dipping=1       coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# grupo            -0.0692   7.43e+05  -9.32e-08      1.000   -1.46e+06    1.46e+06
# genero           -0.0173   2.97e+06  -5.82e-09      1.000   -5.82e+06    5.82e+06
# =================================================================================
#
#
# =================================Predict Proba================================
#
#
# [[0.57299963 0.42700037]
#  [0.57299963 0.42700037]
#  [0.57299963 0.42700037]
#  ...
#  [0.57299963 0.42700037]
#  [0.57299963 0.42700037]
#  [0.57299963 0.42700037]]
#
#
# ====================================Score=====================================
#
#
# 0.5730034296913278
# Optimization terminated successfully.
#          Current function value: 0.687691
#          Iterations 4
# Var Independente = ['grupo', 'genero']
# Var dependente = Non Dipping
# Grupo = 5
#
#
#
#
# =================================Model Summary================================
#
#
#                           MNLogit Regression Results
# ==============================================================================
# Dep. Variable:            Non Dipping   No. Observations:                 1250
# Model:                        MNLogit   Df Residuals:                     1248
# Method:                           MLE   Df Model:                            1
# Date:                Fri, 24 Mar 2023   Pseudo R-squ.:               5.627e-05
# Time:                        12:25:07   Log-Likelihood:                -859.61
# converged:                       True   LL-Null:                       -859.66
# Covariance Type:            nonrobust   LLR p-value:                    0.7558
# =================================================================================
# Non Dipping=1       coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# grupo            -0.0366      0.020     -1.836      0.066      -0.076       0.002
# genero           -0.0378      0.121     -0.311      0.756      -0.276       0.200
# =================================================================================
#
#
# =================================Predict Proba================================
#
#
# [[0.55498585 0.44501415]
#  [0.55498585 0.44501415]
#  [0.55498585 0.44501415]
#  ...
#  [0.54575378 0.45424622]
#  [0.54575378 0.45424622]
#  [0.55498585 0.44501415]]
#
#
# ====================================Score=====================================
#
#
# 0.552
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.688679
#          Iterations: 35
# Var Independente = ['grupo', 'genero']
# Var dependente = Non Dipping
# Grupo = 6
#
#
#
#
# =================================Model Summary================================
#
#
#                           MNLogit Regression Results
# ==============================================================================
# Dep. Variable:            Non Dipping   No. Observations:                 3737
# Model:                        MNLogit   Df Residuals:                     3735
# Method:                           MLE   Df Model:                            1
# Date:                Fri, 24 Mar 2023   Pseudo R-squ.:               3.265e-11
# Time:                        12:25:07   Log-Likelihood:                -2573.6
# converged:                      False   LL-Null:                       -2573.6
# Covariance Type:            nonrobust   LLR p-value:                    0.9997
# =================================================================================
# Non Dipping=1       coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# grupo            -0.0307        nan        nan        nan         nan         nan
# genero           -0.0051        nan        nan        nan         nan         nan
# =================================================================================
#
#
# =================================Predict Proba================================
#
#
# [[0.5472291 0.4527709]
#  [0.5472291 0.4527709]
#  [0.5472291 0.4527709]
#  ...
#  [0.5472291 0.4527709]
#  [0.5472291 0.4527709]
#  [0.5472291 0.4527709]]
#
#
# ====================================Score=====================================
#
#
# 0.5472303987155472
# Optimization terminated successfully.
#          Current function value: 0.229035
#          Iterations 7
# Var Independente = ['grupo', 'genero']
# Var dependente = Extreme Dipping
# Grupo = 1
#
#
#
#
# =================================Model Summary================================
#
#
#                           MNLogit Regression Results
# ==============================================================================
# Dep. Variable:        Extreme Dipping   No. Observations:                 2979
# Model:                        MNLogit   Df Residuals:                     2977
# Method:                           MLE   Df Model:                            1
# Date:                Fri, 24 Mar 2023   Pseudo R-squ.:               6.387e-05
# Time:                        12:25:07   Log-Likelihood:                -682.30
# converged:                       True   LL-Null:                       -682.34
# Covariance Type:            nonrobust   LLR p-value:                    0.7678
# =====================================================================================
# Extreme Dipping=1       coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# grupo                -2.7356      0.077    -35.468      0.000      -2.887      -2.584
# genero               -0.2088      0.730     -0.286      0.775      -1.639       1.221
# =====================================================================================
#
#
# =================================Predict Proba================================
#
#
# [[0.9391418 0.0608582]
#  [0.9391418 0.0608582]
#  [0.9391418 0.0608582]
#  ...
#  [0.9391418 0.0608582]
#  [0.9391418 0.0608582]
#  [0.9391418 0.0608582]]
#
#
# ====================================Score=====================================
#
#
# 0.9392413561597852
# C:\Users\marta\anaconda3\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# C:\Users\marta\anaconda3\lib\site-packages\statsmodels\discrete\discrete_model.py:4247: RuntimeWarning: invalid value encountered in sqrt
#   bse = np.sqrt(np.diag(self.cov_params()))
# C:\Users\marta\anaconda3\lib\site-packages\sklearn\utils\validation.py:1111: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\marta\anaconda3\lib\site-packages\sklearn\utils\validation.py:1111: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Optimization terminated successfully.
#          Current function value: 0.244327
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.232671
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.282012
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.268677
#          Iterations 6
# Var Independente = ['grupo', 'genero']
# Var dependente = Extreme Dipping
# Grupo = 5
#
#
#
#
# =================================Model Summary================================
#
#
#                           MNLogit Regression Results
# ==============================================================================
# Dep. Variable:        Extreme Dipping   No. Observations:                 1250
# Model:                        MNLogit   Df Residuals:                     1248
# Method:                           MLE   Df Model:                            1
# Date:                Fri, 24 Mar 2023   Pseudo R-squ.:               0.0007898
# Time:                        12:25:07   Log-Likelihood:                -335.85
# converged:                       True   LL-Null:                       -336.11
# Covariance Type:            nonrobust   LLR p-value:                    0.4662
# =====================================================================================
# Extreme Dipping=1       coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# grupo                -0.4780      0.036    -13.337      0.000      -0.548      -0.408
# genero               -0.1637      0.223     -0.734      0.463      -0.601       0.274
# =====================================================================================
#
#
# =================================Predict Proba================================
# C:\Users\marta\anaconda3\lib\site-packages\sklearn\utils\validation.py:1111: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [[0.92762611 0.07237389]
#  [0.92762611 0.07237389]
#  [0.92762611 0.07237389]
#  ...
#  [0.91643436 0.08356564]
#  [0.91643436 0.08356564]
#  [0.92762611 0.07237389]]
#
#
# ====================================Score=====================================
#
#
# 0.924
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.244129
#          Iterations: 35
# Var Independente = ['grupo', 'genero']
# Var dependente = Extreme Dipping
# Grupo = 6
#
#
#
#
# =================================Model Summary================================
#
#
#                           MNLogit Regression Results
# ==============================================================================
# Dep. Variable:        Extreme Dipping   No. Observations:                 3737
# Model:                        MNLogit   Df Residuals:                     3735
# Method:                           MLE   Df Model:                            1
# Date:                Fri, 24 Mar 2023   Pseudo R-squ.:               2.233e-12
# Time:                        12:25:07   Log-Likelihood:                -912.31
# converged:                      False   LL-Null:                       -912.31
# Covariance Type:            nonrobust   LLR p-value:                    0.9999
# =====================================================================================
# Extreme Dipping=1       coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# grupo                -0.4287        nan        nan        nan         nan         nan
# genero               -0.0714        nan        nan        nan         nan         nan
# =====================================================================================
#
#
# =================================Predict Proba================================
#
#
# [[0.93363634 0.06636366]
#  [0.93363634 0.06636366]
#  [0.93363634 0.06636366]
#  ...
#  [0.93363634 0.06636366]
#  [0.93363634 0.06636366]
#  [0.93363634 0.06636366]]
#
#
# ====================================Score=====================================
#
#
# 0.9336366069039337
# Optimization terminated successfully.
#          Current function value: 0.404743
#          Iterations 6
# Var Independente = ['grupo', 'genero']
# Var dependente = Reverse Dipping
# Grupo = 1
#
#
#
#
# =================================Model Summary================================
#
#
#                           MNLogit Regression Results
# ==============================================================================
# Dep. Variable:        Reverse Dipping   No. Observations:                 2979
# Model:                        MNLogit   Df Residuals:                     2977
# Method:                           MLE   Df Model:                            1
# Date:                Fri, 24 Mar 2023   Pseudo R-squ.:               0.0004540
# Time:                        12:25:07   Log-Likelihood:                -1205.7
# converged:                       True   LL-Null:                       -1206.3
# Covariance Type:            nonrobust   LLR p-value:                    0.2953
# =====================================================================================
# Reverse Dipping=1       coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# grupo                -1.8223      0.053    -34.193      0.000      -1.927      -1.718
# genero                0.4360      0.399      1.093      0.274      -0.346       1.218
# =====================================================================================
#
#
# =================================Predict Proba================================
#
#
# [[0.86070933 0.13929067]
#  [0.86070933 0.13929067]
#  [0.86070933 0.13929067]
#  ...
#  [0.86070933 0.13929067]
#  [0.86070933 0.13929067]
#  [0.86070933 0.13929067]]
#
#
# ====================================Score=====================================
#
#
# 0.8600201409869084
# Optimization terminated successfully.
#          Current function value: 0.432869
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.495060
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.362094
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.473101
#          Iterations 5
# Var Independente = ['grupo', 'genero']
# Var dependente = Reverse Dipping
# Grupo = 5
#
#
#
#
# =================================Model Summary================================
#
#
#                           MNLogit Regression Results
# ==============================================================================
# Dep. Variable:        Reverse Dipping   No. Observations:                 1250
# Model:                        MNLogit   Df Residuals:                     1248
# Method:                           MLE   Df Model:                            1
# Date:                Fri, 24 Mar 2023   Pseudo R-squ.:                0.004025
# Time:                        12:25:07   Log-Likelihood:                -591.38
# converged:                       True   LL-Null:                       -593.77
# Covariance Type:            nonrobust   LLR p-value:                   0.02880
# =====================================================================================
# Reverse Dipping=1       coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# grupo                -0.2563      0.024    -10.636      0.000      -0.304      -0.209
# genero               -0.3350      0.152     -2.205      0.027      -0.633      -0.037
# =====================================================================================
#
#
# =================================Predict Proba================================
# C:\Users\marta\anaconda3\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# C:\Users\marta\anaconda3\lib\site-packages\statsmodels\discrete\discrete_model.py:4247: RuntimeWarning: invalid value encountered in sqrt
#   bse = np.sqrt(np.diag(self.cov_params()))
# C:\Users\marta\anaconda3\lib\site-packages\sklearn\utils\validation.py:1111: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\marta\anaconda3\lib\site-packages\sklearn\utils\validation.py:1111: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\marta\anaconda3\lib\site-packages\sklearn\utils\validation.py:1111: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\marta\anaconda3\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# C:\Users\marta\anaconda3\lib\site-packages\statsmodels\discrete\discrete_model.py:4247: RuntimeWarning: invalid value encountered in sqrt
#   bse = np.sqrt(np.diag(self.cov_params()))
# [[0.83393202 0.16606798]
#  [0.83393202 0.16606798]
#  [0.83393202 0.16606798]
#  ...
#  [0.78352433 0.21647567]
#  [0.78352433 0.21647567]
#  [0.83393202 0.16606798]]
#
#
# ====================================Score=====================================
#
#
# 0.8176
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.401950
#          Iterations: 35
# Var Independente = ['grupo', 'genero']
# Var dependente = Reverse Dipping
# Grupo = 6
#
#
#
#
# =================================Model Summary================================
#
#
#                           MNLogit Regression Results
# ==============================================================================
# Dep. Variable:        Reverse Dipping   No. Observations:                 3737
# Model:                        MNLogit   Df Residuals:                     3735
# Method:                           MLE   Df Model:                            1
# Date:                Fri, 24 Mar 2023   Pseudo R-squ.:               1.447e-10
# Time:                        12:25:07   Log-Likelihood:                -1502.1
# converged:                      False   LL-Null:                       -1502.1
# Covariance Type:            nonrobust   LLR p-value:                    0.9995
# =====================================================================================
# Reverse Dipping=1       coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# grupo                -0.2966        nan        nan        nan         nan         nan
# genero               -0.0495        nan        nan        nan         nan         nan
# =====================================================================================
#
#
# =================================Predict Proba================================
# C:\Users\marta\anaconda3\lib\site-packages\sklearn\utils\validation.py:1111: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [[0.86163877 0.13836123]
#  [0.86163877 0.13836123]
#  [0.86163877 0.13836123]
#  ...
#  [0.86163877 0.13836123]
#  [0.86163877 0.13836123]
#  [0.86163877 0.13836123]]
#
#
# ====================================Score=====================================
#
#
# 0.8616537329408617
# Optimization terminated successfully.
#          Current function value: 0.485980
#          Iterations 6
# Var Independente = ['grupo', 'genero']
# Var dependente = Morning Surge
# Grupo = 1
#
#
#
#
# =================================Model Summary================================
#
#
#                           MNLogit Regression Results
# ==============================================================================
# Dep. Variable:          Morning Surge   No. Observations:                 2979
# Model:                        MNLogit   Df Residuals:                     2977
# Method:                           MLE   Df Model:                            1
# Date:                Fri, 24 Mar 2023   Pseudo R-squ.:                0.001488
# Time:                        12:25:07   Log-Likelihood:                -1447.7
# converged:                       True   LL-Null:                       -1449.9
# Covariance Type:            nonrobust   LLR p-value:                   0.03781
# ===================================================================================
# Morning Surge=1       coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# grupo              -1.4377      0.047    -30.693      0.000      -1.530      -1.346
# genero             -1.0746      0.602     -1.785      0.074      -2.255       0.106
# ===================================================================================
#
#
# =================================Predict Proba================================
#
#
# [[0.80837391 0.19162609]
#  [0.80837391 0.19162609]
#  [0.80837391 0.19162609]
#  ...
#  [0.80837391 0.19162609]
#  [0.80837391 0.19162609]
#  [0.80837391 0.19162609]]
#
#
# ====================================Score=====================================
#
#
# 0.8096676737160121
# Optimization terminated successfully.
#          Current function value: 0.457836
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.417383
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.477738
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.410997
#          Iterations 6
# Var Independente = ['grupo', 'genero']
# Var dependente = Morning Surge
# Grupo = 5
#
#
#
#
# =================================Model Summary================================
#
#
#                           MNLogit Regression Results
# ==============================================================================
# Dep. Variable:          Morning Surge   No. Observations:                 1250
# Model:                        MNLogit   Df Residuals:                     1248
# Method:                           MLE   Df Model:                            1
# Date:                Fri, 24 Mar 2023   Pseudo R-squ.:                0.009647
# Time:                        12:25:08   Log-Likelihood:                -513.75
# converged:                       True   LL-Null:                       -518.75
# Covariance Type:            nonrobust   LLR p-value:                  0.001558
# ===================================================================================
# Morning Surge=1       coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# grupo              -0.4367      0.033    -13.255      0.000      -0.501      -0.372
# genero              0.5756      0.189      3.048      0.002       0.205       0.946
# ===================================================================================
#
#
# =================================Predict Proba================================
#
#
# [[0.83379426 0.16620574]
#  [0.83379426 0.16620574]
#  [0.83379426 0.16620574]
#  ...
#  [0.89739268 0.10260732]
#  [0.89739268 0.10260732]
#  [0.83379426 0.16620574]]
#
#
# ====================================Score=====================================
#
#
# 0.8544
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.467451
#          Iterations: 35
# Var Independente = ['grupo', 'genero']
# Var dependente = Morning Surge
# Grupo = 6
#
#
#
#
# =================================Model Summary================================
#
#
#                           MNLogit Regression Results
# ==============================================================================
# Dep. Variable:          Morning Surge   No. Observations:                 3737
# Model:                        MNLogit   Df Residuals:                     3735
# Method:                           MLE   Df Model:                            1
# Date:                Fri, 24 Mar 2023   Pseudo R-squ.:               7.856e-11
# Time:                        12:25:08   Log-Likelihood:                -1746.9
# converged:                      False   LL-Null:                       -1746.9
# Covariance Type:            nonrobust   LLR p-value:                    0.9996
# ===================================================================================
# Morning Surge=1       coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# grupo              -0.2487        nan        nan        nan         nan         nan
# genero             -0.0415        nan        nan        nan         nan         nan
# ===================================================================================
#
#
# =================================Predict Proba================================
# C:\Users\marta\anaconda3\lib\site-packages\sklearn\utils\validation.py:1111: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\marta\anaconda3\lib\site-packages\sklearn\utils\validation.py:1111: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\marta\anaconda3\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# C:\Users\marta\anaconda3\lib\site-packages\statsmodels\discrete\discrete_model.py:4247: RuntimeWarning: invalid value encountered in sqrt
#   bse = np.sqrt(np.diag(self.cov_params()))
# C:\Users\marta\anaconda3\lib\site-packages\sklearn\utils\validation.py:1111: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [[0.82256966 0.17743034]
#  [0.82256966 0.17743034]
#  [0.82256966 0.17743034]
#  ...
#  [0.82256966 0.17743034]
#  [0.82256966 0.17743034]
#  [0.82256966 0.17743034]]
#
#
# ====================================Score=====================================
#
#
# 0.8225849611988226
# Optimization terminated successfully.
#          Current function value: 0.007942
#          Iterations 20
# Var Independente = ['grupo', 'genero']
# Var dependente = Masked
# Grupo = 1
#
#
#
#
# =================================Model Summary================================
#
#
#                           MNLogit Regression Results
# ==============================================================================
# Dep. Variable:                 Masked   No. Observations:                 2979
# Model:                        MNLogit   Df Residuals:                     2977
# Method:                           MLE   Df Model:                            1
# Date:                Fri, 24 Mar 2023   Pseudo R-squ.:                0.001712
# Time:                        12:25:08   Log-Likelihood:                -23.660
# converged:                       True   LL-Null:                       -23.701
# Covariance Type:            nonrobust   LLR p-value:                    0.7757
# ==============================================================================
#   Masked=1       coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...
#
#
# =================================Predict Proba================================
#
#
# [[0.3199181 0.6800819]
#  [0.3199181 0.6800819]
#  [0.3186091 0.6813909]
#  ...
#  [0.3186091 0.6813909]
#  [0.3186091 0.6813909]
#  [0.3199181 0.6800819]]
#
#
# ====================================Score=====================================
#
#
# 0.6806767116045467
# Optimization terminated successfully.
#          Current function value: 0.619725
#          Iterations 5
# Var Independente = ['grupo', 'genero']
# Var dependente = Whitecoat
# Grupo = 3
#
#
#
#
# =================================Model Summary================================
#
#
#                           MNLogit Regression Results
# ==============================================================================
# Dep. Variable:              Whitecoat   No. Observations:                 3876
# Model:                        MNLogit   Df Residuals:                     3874
# Method:                           MLE   Df Model:                            1
# Date:                Fri, 24 Mar 2023   Pseudo R-squ.:               0.0001354
# Time:                        12:25:24   Log-Likelihood:                -2402.1
# converged:                       True   LL-Null:                       -2402.4
# Covariance Type:            nonrobust   LLR p-value:                    0.4199
# ===============================================================================
# Whitecoat=1       coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------
# grupo           0.2738      0.016     17.454      0.000       0.243       0.305
# genero         -0.0562      0.070     -0.807      0.420      -0.193       0.080
# ===============================================================================
#
#
# =================================Predict Proba================================
#
#
# [[0.31747178 0.68252822]
#  [0.31747178 0.68252822]
#  [0.31747178 0.68252822]
#  ...
#  [0.30551124 0.69448876]
#  [0.30551124 0.69448876]
#  [0.31747178 0.68252822]]
#
#
# ====================================Score=====================================
#
#
# 0.6891124871001032
# Optimization terminated successfully.
#          Current function value: 0.628529
#          Iterations 4
# Var Independente = ['grupo', 'genero']
# Var dependente = Whitecoat
# Grupo = 4
#
#
#
#
# =================================Model Summary================================
#
#
#                           MNLogit Regression Results
# ==============================================================================
# Dep. Variable:              Whitecoat   No. Observations:                 3842
# Model:                        MNLogit   Df Residuals:                     3840
# Method:                           MLE   Df Model:                            1
# Date:                Fri, 24 Mar 2023   Pseudo R-squ.:               1.310e-05
# Time:                        12:25:24   Log-Likelihood:                -2414.8
# converged:                       True   LL-Null:                       -2414.8
# Covariance Type:            nonrobust   LLR p-value:                    0.8014
# ===============================================================================
# Whitecoat=1       coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------
# grupo           0.1839      0.012     15.653      0.000       0.161       0.207
# genero          0.0174      0.069      0.252      0.801      -0.118       0.153
# ===============================================================================
#
#
# =================================Predict Proba================================
#
#
# [[0.3239943  0.6760057 ]
#  [0.32019646 0.67980354]
#  [0.3239943  0.6760057 ]
#  ...
#  [0.3239943  0.6760057 ]
#  [0.3239943  0.6760057 ]
#  [0.3239943  0.6760057 ]]
#
#
# ====================================Score=====================================
#
#
# 0.6777719937532535
# Optimization terminated successfully.
# C:\Users\marta\anaconda3\lib\site-packages\sklearn\utils\validation.py:1111: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\marta\anaconda3\lib\site-packages\sklearn\utils\validation.py:1111: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\marta\anaconda3\lib\site-packages\sklearn\utils\validation.py:1111: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\marta\anaconda3\lib\site-packages\sklearn\utils\validation.py:1111: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#          Current function value: 0.607246
#          Iterations 5
# Var Independente = ['grupo', 'genero']
# Var dependente = Whitecoat
# Grupo = 5
#
#
#
#
# =================================Model Summary================================
#
#
#                           MNLogit Regression Results
# ==============================================================================
# Dep. Variable:              Whitecoat   No. Observations:                 3836
# Model:                        MNLogit   Df Residuals:                     3834
# Method:                           MLE   Df Model:                            1
# Date:                Fri, 24 Mar 2023   Pseudo R-squ.:               0.0001449
# Time:                        12:25:24   Log-Likelihood:                -2329.4
# converged:                       True   LL-Null:                       -2329.7
# Covariance Type:            nonrobust   LLR p-value:                    0.4113
# ===============================================================================
# Whitecoat=1       coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------
# grupo           0.1681      0.010     17.589      0.000       0.149       0.187
# genero          0.0584      0.071      0.821      0.412      -0.081       0.198
# ===============================================================================
#
#
# =================================Predict Proba================================
#
#
# [[0.30144011 0.69855989]
#  [0.2893087  0.7106913 ]
#  [0.2893087  0.7106913 ]
#  ...
#  [0.30144011 0.69855989]
#  [0.30144011 0.69855989]
#  [0.2893087  0.7106913 ]]
#
#
# ====================================Score=====================================
#
#
# 0.704118873826903
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.002214
#          Iterations: 35
# Var Independente = ['grupo', 'genero']
# Var dependente = Normotenso
# Grupo = 1
#
#
#
#
# =================================Model Summary================================
#
#
#                           MNLogit Regression Results
# ==============================================================================
# Dep. Variable:             Normotenso   No. Observations:                 3813
# Model:                        MNLogit   Df Residuals:                     3811
# Method:                           MLE   Df Model:                            1
# Date:                Fri, 24 Mar 2023   Pseudo R-squ.:                 0.08700
# Time:                        12:25:24   Log-Likelihood:                -8.4416
# converged:                      False   LL-Null:                       -9.2460
# Covariance Type:            nonrobust   LLR p-value:                    0.2047
# ================================================================================
# Normotenso=1       coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# grupo          -36.3578   1.71e+06  -2.13e-05      1.000   -3.35e+06    3.35e+06
# genero          28.9164   1.71e+06   1.69e-05      1.000   -3.35e+06    3.35e+06
# ================================================================================
#
#
# =================================Predict Proba================================
#
#
# [[9.99790011e-01 2.09988854e-04]
#  [9.99790011e-01 2.09988854e-04]
#  [9.99673180e-01 3.26819555e-04]
#  ...
#  [9.99790011e-01 2.09988854e-04]
#  [9.99673180e-01 3.26819555e-04]
#  [9.99673180e-01 3.26819555e-04]]
#
#
# ====================================Score=====================================
#
#
# 0.999737739312877
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.002184
#          Iterations: 35
# Var Independente = ['grupo', 'genero']
# Var dependente = Normotenso
# Grupo = 3
#
#
#
#
# =================================Model Summary================================
#
#
#                           MNLogit Regression Results
# ==============================================================================
# Dep. Variable:             Normotenso   No. Observations:                 3876
# Model:                        MNLogit   Df Residuals:                     3874
# Method:                           MLE   Df Model:                            1
# Date:                Fri, 24 Mar 2023   Pseudo R-squ.:                 0.08599
# Time:                        12:25:24   Log-Likelihood:                -8.4659
# converged:                      False   LL-Null:                       -9.2624
# Covariance Type:            nonrobust   LLR p-value:                    0.2069
# ================================================================================
# Normotenso=1       coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# grupo          -19.4104   8.69e+06  -2.23e-06      1.000    -1.7e+07     1.7e+07
# genero          50.7656   2.61e+07   1.95e-06      1.000   -5.11e+07    5.11e+07
# ================================================================================
#
#
# =================================Predict Proba================================
#
#
# [[9.99679406e-01 3.20593572e-04]
#  [9.99679406e-01 3.20593572e-04]
#  [9.99679406e-01 3.20593572e-04]
#  ...
#  [9.99793423e-01 2.06577094e-04]
#  [9.99793423e-01 2.06577094e-04]
#  [9.99679406e-01 3.20593572e-04]]
#
#
# ====================================Score=====================================
#
#
# 0.9997420020639834
# C:\Users\marta\anaconda3\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# C:\Users\marta\anaconda3\lib\site-packages\sklearn\utils\validation.py:1111: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\marta\anaconda3\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# C:\Users\marta\anaconda3\lib\site-packages\sklearn\utils\validation.py:1111: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\marta\anaconda3\lib\site-packages\sklearn\utils\validation.py:1111: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Optimization terminated successfully.
#          Current function value: 0.006301
#          Iterations 12
# Var Independente = ['grupo', 'genero']
# Var dependente = Normotenso
# Grupo = 4
#
#
#
#
# =================================Model Summary================================
#
#
#                           MNLogit Regression Results
# ==============================================================================
# Dep. Variable:             Normotenso   No. Observations:                 3842
# Model:                        MNLogit   Df Residuals:                     3840
# Method:                           MLE   Df Model:                            1
# Date:                Fri, 24 Mar 2023   Pseudo R-squ.:                 0.01045
# Time:                        12:25:24   Log-Likelihood:                -24.209
# converged:                       True   LL-Null:                       -24.464
# Covariance Type:            nonrobust   LLR p-value:                    0.4746
# ================================================================================
# Normotenso=1       coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# grupo           -1.9085      0.250     -7.632      0.000      -2.399      -1.418
# genero           0.8471      1.225      0.691      0.489      -1.554       3.248
# ================================================================================
#
#
# =================================Predict Proba================================
#
#
# [[9.99346298e-01 6.53701634e-04]
#  [9.99070937e-01 9.29062863e-04]
#  [9.99346298e-01 6.53701634e-04]
#  ...
#  [9.99346298e-01 6.53701634e-04]
#  [9.99346298e-01 6.53701634e-04]
#  [9.99346298e-01 6.53701634e-04]]
#
#
# ====================================Score=====================================
#
#
# 0.9992191566892243
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.004055
#          Iterations: 35
# Var Independente = ['grupo', 'genero']
# Var dependente = Normotenso
# Grupo = 5
#
#
#
#
# =================================Model Summary================================
#
#
#                           MNLogit Regression Results
# ==============================================================================
# Dep. Variable:             Normotenso   No. Observations:                 3836
# Model:                        MNLogit   Df Residuals:                     3834
# Method:                           MLE   Df Model:                            1
# Date:                Fri, 24 Mar 2023   Pseudo R-squ.:                 0.09133
# Time:                        12:25:24   Log-Likelihood:                -15.554
# converged:                      False   LL-Null:                       -17.118
# Covariance Type:            nonrobust   LLR p-value:                   0.07701
# ================================================================================
# Normotenso=1       coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# grupo           -5.0154   1223.034     -0.004      0.997   -2402.119    2392.088
# genero          18.3007   6115.172      0.003      0.998    -1.2e+04     1.2e+04
# ================================================================================
#
#
# =================================Predict Proba================================
#
#
# [[9.99650037e-01 3.49963137e-04]
#  [9.99275583e-01 7.24417392e-04]
#  [9.99275583e-01 7.24417392e-04]
#  ...
#  [9.99650037e-01 3.49963137e-04]
#  [9.99650037e-01 3.49963137e-04]
#  [9.99275583e-01 7.24417392e-04]]
#
#
# ====================================Score=====================================
#
#
# 0.9994786235662148
# C:\Users\marta\anaconda3\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# C:\Users\marta\anaconda3\lib\site-packages\sklearn\utils\validation.py:1111: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
import statsmodels.api as sm
import numpy as np

y_dependente = mapa_variaveis[['Whitecoat']] #, 'cat. imc', 'genero']]
#print (y_dependente)
X_independente = mapa_variaveis[['grupo', 'genero']]
print (X_independente)
sm_model = sm.MNLogit(y_dependente, X_independente).fit()

# print(sm_model.pvalues)
#dir(sm_model)
sm_model.summary()
# Out:
#       grupo  genero
# 0         1       0
# 1         1       0
# 2         1       0
# 3         1       0
# 4         1       0
# ...     ...     ...
# 2603      1       0
# 2604      1       0
# 2605      1       0
# 2606      1       0
# 2607      1       0
#
# [2608 rows x 2 columns]
# Optimization terminated successfully.
#          Current function value: 0.646863
#          Iterations 4
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                           MNLogit Regression Results
# ==============================================================================
# Dep. Variable:              Whitecoat   No. Observations:                 2608
# Model:                        MNLogit   Df Residuals:                     2606
# Method:                           MLE   Df Model:                            1
# Date:                Fri, 24 Mar 2023   Pseudo R-squ.:                 0.01558
# Time:                        12:25:24   Log-Likelihood:                -1687.0
# converged:                       True   LL-Null:                       -1713.7
# Covariance Type:            nonrobust   LLR p-value:                 2.714e-13
# ===============================================================================
# Whitecoat=1       coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------
# grupo           0.7624      0.051     14.871      0.000       0.662       0.863
# genero         -0.6263      0.086     -7.314      0.000      -0.794      -0.458
# ===============================================================================
# """

# %%
y_dependente = mapa_variaveis[['Whitecoat']] #, 'cat. imc', 'genero']]
x_independente = mapa_variaveis[['grupo', 'genero']]

from sklearn.linear_model import LogisticRegression
#X = np.asarray(grupos[0]["Dipping"]).astype(int)[:, np.newaxis]

clf = LogisticRegression(random_state=0).fit(x_independente, y_dependente)
clf.predict(x_independente)

clf.predict_proba(x_independente)


clf.score(x_independente, y_dependente)
# Out:
# C:\Users\marta\anaconda3\lib\site-packages\sklearn\utils\validation.py:1111: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 0.6334355828220859

# %%
#print(clf.__doc__)

# %%
#from sklearn import datasets, linear_model
#from sklearn.feature_selection import chi2
#print(list(grupos[1].columns))

# %%
#import statsmodels.api as sm
#import numpy as np
#
#X = np.asarray(grupos[0]["Whitecoat"]).astype(int)[:, np.newaxis]
#sm_model = sm.Logit(grupos[0]["genero"], sm.add_constant(X)).fit(disp=0)
#print(sm_model.pvalues)
#sm_model.summary()

# %%
#from sklearn.linear_model import LogisticRegression
##X = np.asarray(grupos[0]["Dipping"]).astype(int)[:, np.newaxis]
#
#
#clf = LogisticRegression(random_state=0).fit(X, y_dependente)
#clf.predict(X[:2, :])
#
#clf.predict_proba(X[:2, :])
#
#
#clf.score(X_independente, y_dependente)
#y_dependente = mapa_variaveis[['Whitecoat']] #, 'cat. imc', 'genero']]
#X_independente = mapa_variaveis[['Grupo', 'genero']]

# %%
#    Cálculo do Desvio-padrão Conjunto pelo método D de Cohen
#
#  Sob a hipótese de igualdade de variâncias na população, supõe-se que a variância coletiva (conjunta)
#  da amostra proporciona maior precisão na estimativa da variância populacional do que as variâncias
#  individuais da amostra. Esta precisão mais elevada pode conduzir a um aumento do poder estatístico
#  quando utilizado em testes de hipótese estatística, tais como o teste t de Student.
#  É também empregado no cálculo das medidas de tamanho do efeito.
#  s: desvio-padrão
#  n: tamanho da amostra
#  k: número de tamanhos de amostras
#
from statistics import mean, stdev
from math import sqrt

# test conditions
c0 = [2, 4, 7, 3, 7, 35, 8, 9]
c1 = [i * 2 for i in c0]

cohens_d = (mean(c0) - mean(c1)) / (sqrt((stdev(c0) ** 2 + stdev(c1) ** 2) / 2))

print(cohens_d)
# Out:
# -0.5567679522645598
